# %% [markdown]
# <a href="https://colab.research.google.com/github/sh-0620/solar/blob/main/kaggle_data_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dcc5e41f-4707-42de-8700-734afb7637ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcc5e41f-4707-42de-8700-734afb7637ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 2. Kaggle 설정
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# 3. Kaggle 데이터셋 다운로드
# !kaggle datasets download -d pythonafroz/solar-panel-images
# Out:
# Dataset URL: https://www.kaggle.com/datasets/pythonafroz/solar-panel-images
# License(s): unknown
# ...
# 100% 304M/305M [00:04<00:00, 54.8MB/s]
# 100% 305M/305M [00:04<00:00, 72.2MB/s]

# %%
# 4. Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 5. 다운로드한 파일을 Google Drive로 이동 및 압축 풀기
# !mv solar-panel-images.zip /content/drive/MyDrive/
# !unzip /content/drive/MyDrive/solar-panel-images.zip -d /content/drive/MyDrive/dataset-folder/
# Out:
# Archive:  /content/drive/MyDrive/solar-panel-images.zip
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (1).jpeg
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (10).jpg
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (100).jpg
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (101).jpg
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (102).jpg
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (103).jpg
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (104).jpg
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (105).jpg
#   inflating: /content/drive/MyDrive/dataset-folder/Faulty_solar_panel/Bird-drop/Bird (106).jpg
# ...
